# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
import fastai
import pydicom as dicom
from fast_dicom import *

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.set_device(1)

# %%
PATH = Path("/home/vhl_ai/Data/MRI/DICOMS/")
fnames = list(PATH.glob('NoSpace/image/*'))

# %%
img_path = PATH / 'NoSpace' / 'image'
mask_path = PATH / 'NoSpace' / 'mask'

# %%
study_names = sorted(list(set([i.stem.split('_')[0] for i in img_path.ls() if 'models' not in i.name])))
n_study_names = len(study_names)
trn_names, val_names = study_names[0:int(n_study_names // 1.2)], study_names[int(n_study_names // 1.2):]
split_func = lambda x: x.stem.split('_')[0] in val_names

# %%
img_paths = get_image_files(img_path)
get_y_fn = lambda x: mask_path / x.name

# %%
tfms = get_transforms(do_flip=False)

# %%
codes = ['bg', 'Heart']

db = SegmentationItemList.from_folder(img_path)
db = db.filter_by_func(lambda x: x.stem.split('_')[0] in val_names or x.stem.split('_')[0] in trn_names)
db = db.split_by_valid_func(split_func)
db = db.label_from_func(get_y_fn, classes=codes)
db = db.transform(tfms, size=(256,256), tfm_y=True)
db = db.databunch(bs=16)
db = db.normalize(imagenet_stats)

# %%
db.valid_ds.classes
# Out:
# ['bg', 'Heart']

# %%
db.show_batch(4, figsize=(12,12))

# %%
len(db.train_ds), len(db.valid_ds)
# Out:
# (24122, 5720)

# %%
learn = unet_learner(db, models.resnet34, wd=1e-2)

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(2, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.024719</td>
#       <td>0.021735</td>
#       <td>11:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.021255</td>
#       <td>0.021339</td>
#       <td>11:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('NS 2 epoch frozen')

# %%
learn.recorder.plot_losses()

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(4, 1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.022333</td>
#       <td>0.020908</td>
#       <td>11:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.019521</td>
#       <td>0.021400</td>
#       <td>11:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.016276</td>
#       <td>0.021715</td>
#       <td>11:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.016236</td>
#       <td>0.021704</td>
#       <td>11:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('NS 4 epoch unfrozen')

# %%
learn.recorder.plot_losses()

# %%
learn.show_results(rows=10)

# %%
#learn.load('4 epoch unfrozen');

# %%
class DicomEval():
    def __init__(self, learn, path):
        #Append miou callback for learn
        n_classes = learn.data.c
        self.learn = learn
        self.orig_data = learn.data
        
        self.path = path
        
        self.conf_mats = np.zeros((n_classes, n_classes))
        
    def one_study(self, study_name):
        res = []
        ys = None
        for ind, axis in enumerate(['0']):#, '1', '2']):
            data, orig_shape = dataset_val(self.path, study_name, axis, codes=["background", "Heart"])
            self.learn.data = data
            preds = self.learn.get_preds()
            xs = preds[0]
            xs = F.interpolate(xs, size=orig_shape)
            
            if ind == 1:
                xs = xs.permute(2, 1, 0, 3) #3,0
            elif ind == 2:
                xs = xs.permute(2,1,3,0)
            res.append(xs)
            if ys is None:
                ys = preds[1]
                ys = F.interpolate(ys.float(), size=orig_shape).long()
            
        self.learn.data = self.orig_data
        
        #Here we reshape the res tensors back.
#         targ_shape = list(res[0].shape[1:])
#         targ_shape.insert(0, res[1].shape[0])
#         res = [resize_3d(i, size=tuple(targ_shape)) for i in res]
#         targ_shape[1] = 1
#         ys = resize_3d(ys, size=tuple(targ_shape))

 

        res = sum(res).argmax(1)

        #res = res[2].argmax(1)
        return res, ys[:,0]
    
def save_3d_model(save_folder, study_name, dc_eval, spacing=[1.,1.,1.], classes=['background', 'RA',  'RV', 'LA', 'LV']):
    res, y = dc_eval.one_study(study_name)
    #res = res.permute(2,1,0)
    
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    
    save_names = [save_folder / f"{study_name}_{i}.stl" for i in classes]

    for ind, save_name in enumerate(save_names):
        if "background" in save_name.stem:
            continue
        verts, faces, normals, values = measure.marching_cubes_lewiner( (res == ind).float().numpy(), 0, step_size=1, spacing=spacing)

        # Display resulting triangular mesh using Matplotlib. This can also be done
        # with mayavi (see skimage.measure.marching_cubes_lewiner docstring).

        cube = stl_mesh.Mesh(np.zeros(faces.shape[0], dtype=stl_mesh.Mesh.dtype))
        for ind, f in enumerate(faces):
            for j in range(3):
                cube.vectors[ind][j] = verts[f[j],::-1]

        cube.save(str(save_name))
        # Fancy indexing: `verts[faces]` to generate a collection of triangles
        mesh = Poly3DCollection(verts[faces])
        mesh.set_edgecolor('k')
        mesh.set_facecolor('r')
        ax.add_collection3d(mesh)

    ax.set_xlim(0, 200)  # a = 6 (times two for 2nd ellipsoid)
    ax.set_ylim(0, 250)  # b = 10
    ax.set_zlim(0, 250)  # c = 16

    plt.tight_layout()
    plt.show()
    
def dataset_val(path, val_study, axis, codes):
    split_func = lambda x: x.stem.split('_')[0] == val_study and x.stem.split('_')[1] == str(axis)
    
    # TODO: pLEASE FIX
    get_y_fn = lambda x: path / 'mask' / x.name
    
    db = (SegmentationItemList.from_folder(path)
          .filter_by_func(lambda x: 'mask' not in str(x))
          .split_by_valid_func(split_func))
    #Let's keep these in a nicer stack, thanks
    db.valid.items = np.array(sorted(db.valid.items, key=lambda x: int(x.stem.split('_')[-1])))
    orig_shape = db.valid[0].shape[-2:]
    close_shape = [i / 2 for i in orig_shape] if 512 in orig_shape else orig_shape
    close_shape = [int(round(i / 32)*32) for i in close_shape]
    db = (db.label_from_func(get_y_fn, classes=codes)
          .transform(2*[squish()], size=close_shape, resize_method=ResizeMethod.SQUISH, tfm_y=True,)
          .databunch(bs=2,  no_check=True)
          .normalize(imagenet_stats))
    return db, orig_shape

# %%
dc_eval = DicomEval(learn, PATH / 'NoSpace')

# %%
res, y = dc_eval.one_study('HH0311')

# %%
np.shape(res)
# Out:
# torch.Size([120, 512, 512])

# %%
foo = np.flip(res, axis=0)

# %%
plt.set_cmap(plt.gray())
plt.pcolormesh(foo[100, :, :])

# %%
res = np.array(res)
np.min(res), np.max(res)
# Out:
# (0, 1)

# %%
scan_slices = sorted([i for i in Path(PATH / 'HH0311' / 'Raw').ls()])
dc = dicom.read_file(str(scan_slices[100]))
ar = dc.pixel_array
plt.set_cmap(plt.gray())
plt.pcolormesh(ar)

# %%
preds_path = mkdir(Path("/home/vhl_ai/Documents/Alex/MRI_Seg/Preds"), exist_ok=True)

def preds_to_dicom(preds, val_study, flip=False):
    scan_slices = sorted([i for i in Path(PATH / val_study / 'Raw').ls()])
    preds = np.array(preds)
    if flip == True:
        preds = np.flip(preds, axis=0)
    for ind, scan_path in enumerate(scan_slices):
        #print(str(scan_path)[-14:])
        dc = dicom.read_file(str(scan_path))
        px_arr = np.copy(dc.pixel_array)
        pred_ind = preds[ind,...]
        px_arr[pred_ind > 0.5] = 3000
        px_arr[pred_ind < 0.5] = 0
        dc.PixelData = px_arr.tostring()
        dc.save_as(str(Path(preds_path / str(scan_path)[-14:])))
        print("completed frame {}".format(ind))

# %%
preds_to_dicom(res, 'HH0311', flip=True)
# Out:
# completed frame 0
# completed frame 1
# completed frame 2
# completed frame 3
# completed frame 4
# completed frame 5
# completed frame 6
# completed frame 7
# completed frame 8
# completed frame 9
# completed frame 10
# completed frame 11
# completed frame 12
# completed frame 13
# completed frame 14
# completed frame 15
# completed frame 16
# completed frame 17
# completed frame 18
# completed frame 19
# completed frame 20
# completed frame 21
# completed frame 22
# completed frame 23
# completed frame 24
# completed frame 25
# completed frame 26
# completed frame 27
# completed frame 28
# completed frame 29
# completed frame 30
# completed frame 31
# completed frame 32
# completed frame 33
# completed frame 34
# completed frame 35
# completed frame 36
# completed frame 37
# completed frame 38
# completed frame 39
# completed frame 40
# completed frame 41
# completed frame 42
# completed frame 43
# completed frame 44
# completed frame 45
# completed frame 46
# completed frame 47
# completed frame 48
# completed frame 49
# completed frame 50
# completed frame 51
# completed frame 52
# completed frame 53
# completed frame 54
# completed frame 55
# completed frame 56
# completed frame 57
# completed frame 58
# completed frame 59
# completed frame 60
# completed frame 61
# completed frame 62
# completed frame 63
# completed frame 64
# completed frame 65
# completed frame 66
# completed frame 67
# completed frame 68
# completed frame 69
# completed frame 70
# completed frame 71
# completed frame 72
# completed frame 73
# completed frame 74
# completed frame 75
# completed frame 76
# completed frame 77
# completed frame 78
# completed frame 79
# completed frame 80
# completed frame 81
# completed frame 82
# completed frame 83
# completed frame 84
# completed frame 85
# completed frame 86
# completed frame 87
# completed frame 88
# completed frame 89
# completed frame 90
# completed frame 91
# completed frame 92
# completed frame 93
# completed frame 94
# completed frame 95
# completed frame 96
# completed frame 97
# completed frame 98
# completed frame 99
# completed frame 100
# completed frame 101
# completed frame 102
# completed frame 103
# completed frame 104
# completed frame 105
# completed frame 106
# completed frame 107
# completed frame 108
# completed frame 109
# completed frame 110
# completed frame 111
# completed frame 112
# completed frame 113
# completed frame 114
# completed frame 115
# completed frame 116
# completed frame 117
# completed frame 118
# completed frame 119

# %%
shutil.make_archive("/home/vhl_ai/Documents/Alex/MRI_Seg/Preds", 'zip', "/home/vhl_ai/Documents/Alex/MRI_Seg/Preds")
# Out:
# '/home/vhl_ai/Documents/Alex/MRI_Seg/Preds.zip'

# %%
scan_slices = sorted([i for i in preds_path.ls()])
dc = dicom.read_file(str(scan_slices[80]))
ar = dc.pixel_array
plt.set_cmap(plt.gray())
plt.pcolormesh(ar)

# %%
save_3d_model(PATH, val_names[1], dc_eval, classes=['background', 'Heart'], spacing=[0.5, 0.5, 0.5])

# %%
class MriEval():
    def __init__(self, learn, path):
        n_classes = learn.data.c
        self.learn = learn
        self.orig_data = learn.data
        
        self.path = path
        
        self.conf_mats = np.zeros((n_classes, n_classes))
        
    def one_study(self, study_name):
        ys = None
        data = mri_dataset_val(self.path, study_name, codes=["background", "Heart"])
        self.learn.data = data
        preds = self.learn.get_preds()
        xs = preds[0]
        ys = preds[1]
        return xs, ys[:,0]

def mri_dataset_val(path, val_study, codes):
    split_func = lambda x: x.stem.split('_')[0] == val_study
    get_y_fn = lambda x: path / 'mask' / x.name

    db = (SegmentationItemList.from_folder(path)
          .filter_by_func(lambda x: 'mask' not in str(x))
          .split_by_valid_func(split_func))
    
    db.valid.items = np.array(sorted(db.valid.items, key=lambda x: int(x.stem.split('_')[-1])))
    
    db = (db.label_from_func(get_y_fn, classes=codes)
          .transform(size=512, tfm_y=True)
          .databunch(bs=2,  no_check=True)
          .normalize(imagenet_stats))
    return db

# %%
mr_eval = MriEval(learn, PATH / 'NoSpace')

# %%
res, y = mr_eval.one_study('HH0315')

# %%
res.shape, y.shape
# Out:
# (torch.Size([1144, 2, 512, 512]), torch.Size([1144, 512, 512]))

# %%
#foo=np.array(res)[::-1,:,::-1,::-1]
foo=np.array(res)[::-1,...]
test=np.flipud(foo[80,:,:])
test.shape
# Out:
# (512, 512)

# %%
plt.set_cmap(plt.gray())
plt.pcolormesh(test)#np.flipud(foo[80,1, :, :]))

# %%
plt.set_cmap(plt.gray())
plt.pcolormesh(res[80, :, :])

# %%
scan_slices = sorted([i for i in Path(PATH / 'HH0315' / 'Raw').ls()])
dc = dicom.read_file(str(scan_slices[80]))
ar = dc.pixel_array
plt.set_cmap(plt.gray())
plt.pcolormesh(ar)

# %%
def preds_to_dicom(preds, val_study):
    scan_slices = sorted([i for i in Path(PATH / val_study / 'Raw').ls()])
    preds = np.array(preds)[::-1,:,:,:]
    #preds = np.array(preds)[:,:,::-1,::-1]
    for ind, scan_path in enumerate(scan_slices):
        #print(str(scan_path)[-14:])
        dc = dicom.read_file(str(scan_path))
        px_arr = np.copy(dc.pixel_array)
        pred_ind = np.flipud(preds[ind, 1, ...])
        px_arr[pred_ind > 0.5] = 3000
        px_arr[pred_ind < 0.5] = 0
        dc.PixelData = px_arr.tostring()
        dc.save_as(str(Path(PATH / 'test' / 'final' / str(scan_path)[-14:])))
        print("completed frame {}".format(ind))

# %%
preds_to_dicom(res, 'HH0315')
# Out:
# completed frame 0
# completed frame 1
# completed frame 2
# completed frame 3
# completed frame 4
# completed frame 5
# completed frame 6
# completed frame 7
# completed frame 8
# completed frame 9
# completed frame 10
# completed frame 11
# completed frame 12
# completed frame 13
# completed frame 14
# completed frame 15
# completed frame 16
# completed frame 17
# completed frame 18
# completed frame 19
# completed frame 20
# completed frame 21
# completed frame 22
# completed frame 23
# completed frame 24
# completed frame 25
# completed frame 26
# completed frame 27
# completed frame 28
# completed frame 29
# completed frame 30
# completed frame 31
# completed frame 32
# completed frame 33
# completed frame 34
# completed frame 35
# completed frame 36
# completed frame 37
# completed frame 38
# completed frame 39
# completed frame 40
# completed frame 41
# completed frame 42
# completed frame 43
# completed frame 44
# completed frame 45
# completed frame 46
# completed frame 47
# completed frame 48
# completed frame 49
# completed frame 50
# completed frame 51
# completed frame 52
# completed frame 53
# completed frame 54
# completed frame 55
# completed frame 56
# completed frame 57
# completed frame 58
# completed frame 59
# completed frame 60
# completed frame 61
# completed frame 62
# completed frame 63
# completed frame 64
# completed frame 65
# completed frame 66
# completed frame 67
# completed frame 68
# completed frame 69
# completed frame 70
# completed frame 71
# completed frame 72
# completed frame 73
# completed frame 74
# completed frame 75
# completed frame 76
# completed frame 77
# completed frame 78
# completed frame 79
# completed frame 80
# completed frame 81
# completed frame 82
# completed frame 83
# completed frame 84
# completed frame 85
# completed frame 86
# completed frame 87
# completed frame 88
# completed frame 89
# completed frame 90
# completed frame 91
# completed frame 92
# completed frame 93
# completed frame 94
# completed frame 95
# completed frame 96
# completed frame 97
# completed frame 98
# completed frame 99
# completed frame 100
# completed frame 101
# completed frame 102
# completed frame 103
# completed frame 104
# completed frame 105
# completed frame 106
# completed frame 107
# completed frame 108
# completed frame 109
# completed frame 110
# completed frame 111
# completed frame 112
# completed frame 113
# completed frame 114
# completed frame 115
# completed frame 116
# completed frame 117
# completed frame 118
# completed frame 119

# %%
def view_final(val_study, ind):
    scan_slices = sorted([i for i in Path(PATH / 'test' / 'final').ls() if val_study in i.name])
    scan = dicom.read_file(str(scan_slices[ind]))
    return scan

# %%
scan = view_final('HH315', 80)

# %%
ar = scan.pixel_array
plt.set_cmap(plt.gray())
plt.pcolormesh(ar)
